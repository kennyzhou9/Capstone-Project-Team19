# %%
import datetime 
from dateutil.relativedelta import *
import os
import re 
import string
import nltk
import pandas as pd 
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

import matplotlib.pyplot as plt 

from collections import OrderedDict
import langdetect 
from langdetect import DetectorFactory , detect_langs # for dermining language  
DetectorFactory.seed = 0

from google_trans_new import google_translator  # translating words
translator = google_translator()  

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation


from wordcloud import WordCloud 
# %matplotlib inline

# %%
'''Utility Functions'''
def concat_all_dataframes():
    ''' 
    Here we are going to combine all of the training csv's
    Into 1 dataframe that we can use for preprocessing
    
    adjust the path to whereever you are holding the data
    '''
#     path = os.path.join(os.getcwd(),'google_scraping','data')
    path = os.path.join(os.getcwd(),'Scrape_data')
    csvs = os.listdir(path)
    output = pd.DataFrame()
    
    count = 0
    for csv in csvs:
        if csv == '.ipynb_checkpoints':
            continue
        temp = pd.read_csv(os.path.join(path,csv))
        count += 1 
        
        if output.empty:
            output = temp        
        else:
            output = pd.concat([output,temp],axis=0)

    output.reset_index(inplace=True)        
    return output

def clean_translated_reviews(review):
    if 'Google' in review:
        res = review.split('(Original)')[0][23:]
        return res
    else:
        return review

def preprocessing_text(df):
    '''
    Here we are going to clean the text to be in a good format for further analysis 
    
    input: df ; DataFrame object that contains all of the reviews. 
    '''  
    lemm = WordNetLemmatizer()
    df = df.loc[~df.caption.isnull()] # here we are going to only process reviews 
    
    df.caption =  df.caption.apply(lambda review: clean_translated_reviews(review) if 'Google' in review else review)
        
    df.loc[:,'caption'] = df.loc[:,'caption'].apply(str.lower)
    df.loc[:,'caption'] = df.loc[:,'caption'].apply(lambda review: re.sub(r'[^\w\s]','',review)) # removes punctuation
    df.loc[:,'caption'] = df.loc[:,'caption'].apply(lambda review: re.sub('\([^()]*\)','',review)) # removes words within parenthesis 
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    
    df.loc[:,'caption'] = df.loc[:,'caption'].apply(lambda review: emoji_pattern.sub(r'', review)) 
    df.loc[:,'caption_split'] = df.loc[:,'caption'].apply(lambda review: review.split(' '))
    
    clean_reviews = []
    for review_idx , review in df.caption_split.items():
        temp = []
        for idx, word in enumerate(review):
            if word in stop_words:
                continue
            else:
                temp.append(lemm.lemmatize(word))
        
        review_  = ' '.join(temp)
        clean_reviews.append(review_)
    
    df.loc[:,'caption'] = clean_reviews
    df.drop(['Unnamed: 0'],axis=1,inplace=True)
    

    return df


def rating_by_loc(df):
    # here we are going to return the locations that the 
    temp = pd.DataFrame(df.groupby(['address']).rating.value_counts(normalize=True)).sort_index(ascending=True).unstack()
    temp.fillna(0,inplace=True)
    output = {}
    for row in temp.iterrows():
        output[row[0]] = row[1]['rating']
    
    return output
        
def plot_rating_by_loc(d,key):
    # given a key, we are going to be able to plot the rating distribution for that location.
    # the format of the key is 
    d[key].plot(kind='bar');
    plt.title(f'Distribution of ratings from BJs {key} Google Reviews');
    plt.xlabel('rating score');
    plt.xticks(rotation=0)
    plt.ylabel('percent');
    
 
    
def create_language_col(df):
    # Here are we going to make a column of the language of the name
    df['language'] = None 
    for row in df.iterrows():
#         print(row[0])
        if (row[0] in [150,415,987,1120,9780,28028,32711]):
            df.loc[row[0],'language'] = 'en'
        else:
            
            lang = detect_langs(row[1]['caption'].split('(Original) ')[-1]).pop().__repr__()[:2]
            df.loc[row[0],'language'] = lang

    return df


def creating_word_clouds(n_grams_from_reviews,review_score):
    d_n_grams = {gram:freq for gram,freq in zip(n_grams_from_reviews['n-gram'],n_grams_from_reviews['value_count'])}
    plt.figure(figsize=(10,8))
    wordcloud = WordCloud(width=1600, height=800,stopwords=stopwords, background_color="white").generate_from_frequencies(d_n_grams)
    # Display the generated image:
    # the matplotlib way:
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.savefig(f'wordcloud{review_score}.png', facecolor='k', bbox_inches='tight')

    
def convert_relative_to_datetime(df):
    ''' Here we are going to convert relative dates given from google into estimated dates
    
    Input:
        df: The dataframe that is going to contain the relative and retrieval dates
    '''
    for idx , row in df.iterrows():
        print(idx)
        date_scraped = datetime.datetime.strptime(df.loc[idx,'retrieval_date'][:10],'%Y-%m-%d')
        
        relative_date = df.loc[idx,'relative_date'].split()

        if 'hour' in relative_date[1]:
                if relative_date[1] == 'hour':
                    res = date_scraped - relativedelta(hours=1)
                else:
                    res = date_scraped - relativedelta(hours=int(relative_date[0]))
                    
        if 'day' in relative_date[1]:
                if relative_date[1] == 'day':
                    res = date_scraped - relativedelta(days=1)
                else:
                    res = date_scraped - relativedelta(days=int(relative_date[0]))
                    
        if 'week' in relative_date[1]:
                if relative_date[1] == 'week':
                    res = date_scraped - relativedelta(weeks=1)
                else:
                    res = date_scraped - relativedelta(weeks=int(relative_date[0]))
                    
        if 'month' in relative_date[1]:
                if relative_date[1] == 'month':
                    res = date_scraped - relativedelta(months=1)
                else:
                    res = date_scraped - relativedelta(months=int(relative_date[0]))
        elif 'year' in relative_date[1]:
            if relative_date[1] == 'year':
                res = date_scraped - relativedelta(years=1)
            else:
                res = date_scraped - relativedelta(years=int(relative_date[0]))

        df.loc[idx,'relative_date'] = res
        
    return df 


def save_ppl_data(df):
    
    res = df[['relative_date','username','address']]
    res.to_csv('data_for_george.csv')

def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

def ngrams_and_topic_modeling(df,rating_score,return_tfidf = False):
    ''' Here we are going to make a function that print out the topics and the ngrams 
        of a given model based on 
    '''
    # Here we are going to be initializing the vectorizers 
    tfidf_ngram = TfidfVectorizer(max_features=50,ngram_range=(3,5),stop_words='english')
    tfidf_lda = TfidfVectorizer(max_features=50,stop_words='english')
    
    # Here we are going to be creating our df by rewview rating score 
    df_score = df.loc[df['star rating'] == rating_score,'caption']
    df_score_copy = df_score.copy(deep=True)
    
    df_score_transformed = tfidf_ngram.fit_transform(df_score)
    df_score_copy_transformed = tfidf_lda.fit_transform(df_score_copy)

    # getting ngrams and sorting in descending order
    tfidf_series = pd.Series(tfidf_ngram.vocabulary_)
    tfidf_series=tfidf_series.to_frame()
    tfidf_series['n-gram'] = tfidf_series.index
    tfidf_series.index = range(len(tfidf_series.index))
    tfidf_series.rename({0:'value_count'},axis=1,inplace=True)

    top_n_grams = tfidf_series.loc[~tfidf_series['n-gram'].str.contains('google')].sort_values('n-gram',ascending = False)
    print('done with ngrams')
    print('starting lda...')
    # Next we are going to do the Topic Modelling.
#     search_params = {'n_components': list(range(3,8)), 'learning_decay': [.5, .7, .9],'random_state':[23]}
    lda = LatentDirichletAllocation(n_components=3,learning_decay=.5,random_state=23)
#     grid = GridSearchCV(lda,param_grid=search_params,n_jobs=3)
    
    lda.fit(df_score_copy_transformed)
    
    tfidf_lda = pd.DataFrame(df_score_copy_transformed.toarray(),columns=tfidf_lda.get_feature_names())
    topics = display_topics(lda,tfidf_lda.columns,10)
    
    return top_n_grams , topics

# %%
walmart = pd.read_csv('Scrape_data/walmart_reviews_all.csv')
walmart.rename(columns={'review':'caption'},inplace=True)
walmart = preprocessing_text(walmart)

# %%
walmart.loc[walmart.caption.str.contains('english') == True]
# Out:
#         star rating            name  \
# 362               2       David R.F
# 365               5             J P
# 381               3   richard kosta
# 395               3   Pamela Watson
# 416               4      Orkhan Rza
# ...             ...             ...
# 230778            5     Henry Morin
# 230781            5    james nicolo
# 230841            3    Richard Hard
# 231515            5    james nicolo
# 231534            5  Bonnie Woolley
#
#                                                   caption        date  \
# 362     first walmart see staff dont speak english sho...  2021-02-01
# 365                            nobody speaks word english  2021-05-01
# 381     could find many employee speaking english coul...  2021-02-01
# 395     happy could purchase grocery everything else n...  2021-05-01
# 416     one thing like wallmart parking space store go...  2021-05-01
# ...                                                   ...         ...
# 230778  excellent walmart clean organized  well staffe...  2021-05-01
# 230781                         nice go one english spoken  2021-05-01
# 230841  looked help walmart couldnt find single person...  2021-02-01
# 231515                         nice go one english spoken  2021-05-01
# 231534  friendly staff even tough time english helped ...  2021-05-01
#
#         location_code                                      caption_split
# 362               1.0  [first, walmart, i, see, where, some, staff, d...
# 365               1.0             [nobody, speaks, a, word, of, english]
# 381               1.0  [could, not, find, many, employees, speaking, ...
# 395               1.0  [was, happy, i, could, purchase, groceries, an...
# 416               1.0  [one, thing, i, like, about, this, wallmart, i...
# ...               ...                                                ...
# 230778          180.0  [excellent, walmart, very, clean, and, organiz...
# 230781          180.0  [so, nice, to, go, to, one, where, english, is...
# 230841          180.0  [i, looked, for, help, at, this, walmart, and,...
# 231515          180.0  [so, nice, to, go, to, one, where, english, is...
# 231534          180.0  [friendly, staff, even, those, who, have, a, t...
#
# [691 rows x 6 columns]

# %%
ngrams_walmart_5 , topics_5 = ngrams_and_topic_modeling(walmart,rating_score=5)
# Out:
# done with ngrams
# starting lda...

# %%
ngrams_walmart_5
# Out:
#     value_count                      n-gram
# 26           49        walmart super center
# 16           48         walmart great price
# 27           47         walmart great place
# 45           46          walmart good price
# 11           45      walmart favorite store
# 43           44     walmart clean organized
# 44           43           store great price
# 39           42        store friendly staff
# 48           41         store clean stocked
# 42           40       store clean organized
# 23           39      staff friendly helpful
# 36           38             place shop need
# 40           37                open 24 hour
# 20           36             nice place shop
# 29           35            nice clean store
# 33           34            need great price
# 21           33             need good price
# 18           32           love walmart need
# 15           31          love walmart great
# 25           30            love wally world
# 6            29       love shopping walmart
# 31           28              love love love
# 1            27          love going walmart
# 32           26            great store shop
# 37           25            great store need
# 5            24           great store great
# 24           23   great shopping experience
# 17           22           great price great
# 13           21            great price good
# 8            20        great place shopping
# 9            19            great place shop
# 4            18            great place need
# 0            17      great customer service
# 46           16             good price good
# 34           15         good place shopping
# 10           14             good place shop
# 2            13       good customer service
# 41           12      friendly helpful staff
# 19           11         favorite place shop
# 7            10  excellent customer service
# 28            9      enjoy shopping walmart
# 49            8   employee friendly helpful
# 12            7         doesnt love walmart
# 30            6      customer service great
# 22            5       customer service good
# 38            4        clean store friendly
# 47            3        clean friendly staff
# 14            2            best walmart ive
# 35            1           best walmart area
# 3             0             best place shop

# %%
topics_5
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0         great          8563.0          good          7019.5         store
# 1       walmart          6845.9          love          6050.8         clean
# 2         price          4611.5          need          5462.8      shopping
# 3         place          4259.4       service          3818.2       helpful
# 4          shop          3104.0       walmart          2626.0      friendly
# 5          best          2812.4        needed          2287.5         staff
# 6          nice          2446.7      customer          2213.4       stocked
# 7          like          2132.9       looking          1753.2      employee
# 8          time          2126.6     excellent          1430.2          easy
# 9        people          1937.6          help          1322.0          nice
#
#   Topic 2 weights
# 0          6334.8
# 1          4728.2
# 2          3193.4
# 3          3080.5
# 4          3062.9
# 5          2899.7
# 6          2211.0
# 7          2077.4
# 8          1768.2
# 9          1758.9

# %%
ngrams_walmart_4 , topics_4 = ngrams_and_topic_modeling(walmart,rating_score=4)
# Out:
# done with ngrams
# starting lda...

# %%
ngrams_walmart_4
# Out:
#     value_count                     n-gram
# 26           49       walmart super center
# 39           48        walmart great price
# 31           47        walmart great place
# 15           46         walmart good price
# 37           45         usually im looking
# 30           44          use self checkout
# 38           43       store friendly staff
# 0            42        store clean stocked
# 27           41          store clean staff
# 23           40      store clean organized
# 18           39       store clean employee
# 11           38     staff friendly helpful
# 12           37        shelf fully stocked
# 33           36         self checkout line
# 32           35         self checkout lane
# 5            34       selection good price
# 3            33       price good selection
# 13           32        pretty good walmart
# 46           31      pretty decent walmart
# 44           30            place shop need
# 36           29               open 24 hour
# 25           28           nice store clean
# 16           27            nice place shop
# 21           26           nice clean store
# 29           25            need good price
# 17           24      love shopping walmart
# 42           23         like walmart store
# 34           22  great shopping experience
# 1            21           great place shop
# 35           20     great customer service
# 9            19   good shopping experience
# 41           18        good selection item
# 6            17        good selection good
# 20           16            good price good
# 43           15        good place shopping
# 19           14            good place shop
# 4            13            good place need
# 14           12      good customer service
# 24           11     friendly helpful staff
# 2            10  employee friendly helpful
# 10            9     customer service great
# 8             8      customer service good
# 22            7       clean store friendly
# 28            6       clean staff friendly
# 40            5      clean organized store
# 7             4       clean friendly staff
# 48            3         cash register open
# 45            2              big box store
# 47            1        better walmarts ive
# 49            0       better walmarts area

# %%
topics_4
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0       walmart          5872.4          good          3130.1          need
# 1         price          2530.7          nice          2249.8         staff
# 2         place          2151.1         great          1951.9          like
# 3          time          1458.9          item          1658.1      shopping
# 4          good          1373.8         clean          1635.5       stocked
# 5          shop          1304.7       service          1621.5       helpful
# 6         store          1222.3         store          1354.2      friendly
# 7          line          1217.9        needed          1323.3        better
# 8         thing          1215.7     selection          1287.4          love
# 9      checkout          1000.1          busy          1256.9         store
#
#   Topic 2 weights
# 0          2842.7
# 1          1645.8
# 2          1556.1
# 3          1544.9
# 4          1500.1
# 5          1498.1
# 6          1442.5
# 7          1288.5
# 8          1201.5
# 9          1174.2

# %%
ngrams_walmart_3 , topics_3 = ngrams_and_topic_modeling(walmart,rating_score=3)
# Out:
# done with ngrams
# starting lda...

# %%
ngrams_walmart_3
# Out:
#     value_count                       n-gram
# 19           49         walmart super center
# 0            48           walmart good price
# 25           47          walmart dont expect
# 34           46     walmart customer service
# 4            45            use self checkout
# 8            44               use self check
# 40           43       staff friendly helpful
# 38           42       self checkout register
# 20           41           self checkout open
# 1            40           self checkout line
# 21           39              self check line
# 13           38  register open self checkout
# 11           37           register open self
# 48           36           register open line
# 18           35        poor customer service
# 22           34          people wearing mask
# 12           33           open self checkout
# 17           32              open self check
# 15           31                 open 24 hour
# 16           30           need register open
# 45           29           need open register
# 42           28              matter time day
# 30           27               long wait line
# 46           26           long line register
# 39           25           long line checkout
# 43           24              long line check
# 27           23            long line cashier
# 41           22              long check line
# 37           21           line self checkout
# 47           20           line register open
# 7            19          line extremely long
# 44           18             great place shop
# 31           17       great customer service
# 32           16              good place shop
# 9            15            good luck finding
# 5            14        good customer service
# 29           13       customer service skill
# 6            12     customer service lacking
# 14           11        customer service good
# 2            10           checkout line long
# 3             9           checkout lane open
# 26            8              check line long
# 24            7        cashier self checkout
# 23            6           cashier self check
# 33            5            cashier long line
# 35            4            cashier line long
# 36            3           cash register open
# 28            2                big box store
# 49            1      better customer service
# 10            0         bad customer service

# %%
topics_3
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0       walmart          4931.8          need          1591.2          good
# 1         store          1837.4          line          1510.8      customer
# 2          item          1311.2          like          1302.4       service
# 3         shelf          1268.4       cashier          1194.1         staff
# 4         price          1073.0      employee          1191.0         place
# 5         thing           916.9          dont          1077.7           lot
# 6       stocked           844.0          open          1049.7       crowded
# 7          time           766.8          long          1036.3         clean
# 8     selection           658.6      register           898.5          busy
# 9          help           625.0         check           867.8          nice
#
#   Topic 2 weights
# 0          1724.8
# 1          1120.9
# 2          1092.6
# 3          1024.5
# 4          1023.3
# 5          1013.6
# 6           896.4
# 7           840.7
# 8           823.6
# 9           757.4

# %%
ngrams_walmart_2 , topics_2 = ngrams_and_topic_modeling(walmart,rating_score=2)
# Out:
# done with ngrams
# starting lda...

# %%
ngrams_walmart_2
# Out:
#     value_count                     n-gram
# 7            49          worst walmart ive
# 24           48           waited 30 minute
# 38           47           waited 20 minute
# 35           46          use self checkout
# 48           45             use self check
# 5            44  terrible customer service
# 18           43     self checkout register
# 21           42         self checkout open
# 15           41         self checkout line
# 26           40         register open self
# 41           39       register open people
# 34           38         register open long
# 42           37         register open line
# 4            36      poor customer service
# 22           35        people wearing mask
# 32           34         open self checkout
# 27           33            open self check
# 13           32             open long line
# 6            31               open 24 hour
# 30           30     need better management
# 8            29            matter time day
# 29           28             long line self
# 20           27         long line register
# 9            26         long line checkout
# 37           25            long line check
# 43           24          long line cashier
# 40           23         long checkout line
# 2            22              line way long
# 31           21            line super long
# 47           20         line self checkout
# 3            19     line ridiculously long
# 28           18         line register open
# 44           17          line long cashier
# 25           16        line extremely long
# 12           15  horrible customer service
# 45           14      good customer service
# 19           13      employee wearing mask
# 49           12         employee dont know
# 11           11      customer service line
# 1            10  customer service horrible
# 10            9      customer service desk
# 16            8         checkout line open
# 23            7         checkout lane open
# 39            6            check lane open
# 14            5      cashier self checkout
# 46            4          cashier long line
# 36            3         cash register open
# 17            2           cart parking lot
# 0             1       bad customer service
# 33            0                 20 item le

# %%
topics_2
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0       walmart          1736.7          line          1061.9         store
# 1         shelf           954.7        people           890.7      customer
# 2          time           817.2       cashier           828.3       service
# 3          item           724.9          open           770.9         stock
# 4          help           634.4          dont           756.7         staff
# 5          good           528.1          long           674.8      employee
# 6       stocked           500.1      register           666.4           lot
# 7         thing           473.4         place           634.7         dirty
# 8         price           469.6         check           596.4       crowded
# 9          rude           463.8          need           586.5          cart
#
#   Topic 2 weights
# 0          1281.6
# 1           881.0
# 2           803.2
# 3           620.0
# 4           563.3
# 5           538.5
# 6           516.9
# 7           408.4
# 8           404.5
# 9           375.6

# %%
ngrams_walmart_1 , topics_1 = ngrams_and_topic_modeling(walmart,rating_score=1)
# Out:
# done with ngrams
# starting lda...

# %%
ngrams_walmart_1
# Out:
#     value_count                       n-gram
# 5            49            worst walmart ive
# 10           48       worst customer service
# 38           47        went customer service
# 43           46     walmart customer service
# 17           45             waited 30 minute
# 34           44             waited 20 minute
# 46           43               wait 20 minute
# 19           42            use self checkout
# 32           41               use self check
# 12           40    terrible customer service
# 16           39       store customer service
# 49           38           self checkout line
# 21           37              self check line
# 23           36        rude customer service
# 40           35  register open self checkout
# 39           34           register open self
# 15           33           register open line
# 6            32        poor customer service
# 36           31          people wearing mask
# 30           30           open self checkout
# 47           29              open self check
# 28           28              matter time day
# 20           27           line register open
# 48           26        line customer service
# 9            25               line 20 minute
# 2            24    horrible customer service
# 41           23        good customer service
# 13           22            far worst walmart
# 18           21        employee wearing mask
# 4            20              dont waste time
# 42           19           dont speak english
# 25           18            dont answer phone
# 14           17       customer service worst
# 26           16     customer service walmart
# 27           15    customer service terrible
# 35           14        customer service suck
# 11           13       customer service store
# 7            12       customer service skill
# 24           11        customer service rude
# 3            10     customer service manager
# 44            9        customer service line
# 22            8         customer service ive
# 0             7    customer service horrible
# 8             6    customer service employee
# 37            5        customer service desk
# 33            4  customer service department
# 29            3           cash register open
# 45            2             cart parking lot
# 1             1         bad customer service
# 31            0                   20 item le

# %%
topics_1
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0       walmart          3574.1      customer          2467.4      employee
# 1         store          1448.7       service          2405.0         store
# 2         shelf          1350.6          line          1479.8          dont
# 3          item          1336.1        people          1109.5          rude
# 4          time          1239.1      horrible          1076.8          open
# 5          went          1206.9          need          1041.6       cashier
# 6          hour           978.7        minute          1015.6         place
# 7          like           958.5          long           993.3      register
# 8         worst           848.3         phone           922.7         check
# 9      shopping           814.6         going           798.6         staff
#
#   Topic 2 weights
# 0          2152.7
# 1          1628.3
# 2          1625.3
# 3          1515.6
# 4          1433.4
# 5          1414.0
# 6          1381.0
# 7          1218.1
# 8          1036.5
# 9           961.7
